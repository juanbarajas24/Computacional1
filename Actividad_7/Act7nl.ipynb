# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system (nonlineal).
    
    F=-kx + zx³
    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2, z1, z2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + z1 * (x1 - L1)**3 + k2 * (x2 - x1 - L2) + z1* (x1 - x2 - L2)**3) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2) + z2 * (x2 - x1 -L2)**3) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 0.4
k2 = 1.808
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0
#nonlinearity coefficients
z1 = -(1.0/6.0)
z2 = -(1.0/10.0)

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = 1.0
y1 = 0.0
x2 = -(1.0/2.0)
y2 = 0.0

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 50.0
numpoints = 250

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2, z1, z2 ]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('two_springsnl.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file = f)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl.dat', unpack=True)

figure(1, figsize=(6, 6))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(x1, xy, 'b', linewidth=lw)
#plot(x2, y2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Phase plot for x1')
savefig('phaseplot3.1_1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl.dat', unpack=True)

figure(1, figsize=(6, 6))

xlabel('t')
grid(True)
#hold(True)
lw = 1

#plot(x1, xy, 'b', linewidth=lw)
plot(x2, y2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Phase plot for x2')
savefig('phaseplot3.1_2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl.dat', unpack=True)

figure(1, figsize=(15, 9))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(t, x1, 'b', linewidth=lw)
#plot(t, x2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Plot of x1')
savefig('plot3.1_1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl.dat', unpack=True)

figure(1, figsize=(15, 9))

xlabel('t')
grid(True)
#hold(True)
lw = 1

#plot(t, x1, 'b', linewidth=lw)
plot(t, x2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Plot of x2')
savefig('plot3.1_2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl.dat', unpack=True)

figure(1, figsize=(15, 9))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(t, x1, 'b', linewidth=lw)
plot(t, x2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Plot of x1 and x2')
savefig('plot3.1_3.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl.dat', unpack=True)

figure(1, figsize=(6, 4.5))

grid(True)
lw = 1.5

plot(x1,x2, 'darkmagenta', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
x = [-1.5,-1,-0.5,0,0.5,1,1.5]
y = [-1.5,-1,-0.5,0,0.5,1,1.5]
plt.xticks(x)
plt.yticks(y)

title('Plot of x1 vs x2')
savefig('plot3.1_4.png', dpi=100)

# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system (nonlineal).
    
    F=-kx + zx³
    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2, z1, z2 = p

    # Create f = (x1',y1',x2',y2'):
    g = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + z1 * (x1 - L1)**3 + k2 * (x2 - x1 - L2) + z1* (x1 - x2 - L2)**3) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2) + z2 * (x2 - x1 -L2)**3) / m2]
    return g

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 0.4
k2 = 1.808
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0
#nonlinearity coefficients
z1 = -(1.0/6.0)
z2 = -(1.0/10.0)

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = -0.5
y1 = 1.0/2.0
x2 = 3.001
y2 = 5.9

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 200.0
numpoints = 2000

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2, z1, z2 ]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('two_springsnl2.dat', 'w') as g:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file = g)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl2.dat', unpack=True)

figure(1, figsize=(6, 6))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(x1, xy, 'b', linewidth=lw)
#plot(x2, y2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Phase plot for x1')
savefig('phaseplot3.2_1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl2.dat', unpack=True)

figure(1, figsize=(6, 6))

xlabel('t')
grid(True)
#hold(True)
lw = 1

#plot(x1, xy, 'b', linewidth=lw)
plot(x2, y2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Phase plot for x1')
savefig('phaseplot3.2_2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl2.dat', unpack=True)

figure(1, figsize=(6, 6))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(x1, x2, 'darkmagenta', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('x1 vs x2')
savefig('plot3.2_1.png', dpi=100)

# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system (nonlineal).
    
    F=-kx + zx³
    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2, z1, z2 = p

    # Create f = (x1',y1',x2',y2'):
    h = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + z1 * (x1 - L1)**3 + k2 * (x2 - x1 - L2) + z1* (x1 - x2 - L2)**3) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2) + z2 * (x2 - x1 -L2)**3) / m2]
    return h

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 0.4
k2 = 1.808
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0
#nonlinearity coefficients
z1 = -(1.0/6.0)
z2 = -(1.0/10.0)

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = -0.6
y1 = 1.0/2.0
x2 = 3.001
y2 = 5.9

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 200.0
numpoints = 2000

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2, z1, z2 ]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('two_springsnl3.dat', 'w') as h:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file = h)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl3.dat', unpack=True)

figure(1, figsize=(6, 6))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(x1, xy, 'b', linewidth=lw)
#plot(x2, y2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Phase plot for x1')
savefig('phaseplot3.3_1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl3.dat', unpack=True)

figure(1, figsize=(6, 6))

xlabel('t')
grid(True)
#hold(True)
lw = 1

#plot(x1, xy, 'b', linewidth=lw)
plot(x2, y2, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Phase plot for x2')
savefig('phaseplot3.3_2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline
t, x1, xy, x2, y2 = loadtxt('two_springsnl3.dat', unpack=True)

figure(1, figsize=(6, 6))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(x1, x2, 'darkmagenta', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('x1 vs x2')
savefig('plot3.3_1.png', dpi=100)
